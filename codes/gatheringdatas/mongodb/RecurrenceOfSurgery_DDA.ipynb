# %%
import pymongo as mg
import pandas as pd

# %%
client = mg.MongoClient(host='mongodb://localhost:27017')

# %%
database = client['db_medicals']

# %%
collection = database['RecurrenceOfSurgery']

# %%
cursor = collection.find({})
data_list = list(cursor)

# %%
df_ros = pd.DataFrame(data_list)
df_ros.head(10)
# Out:
#                         _id  Unnamed: 0  환자ID  Large Lymphocyte  \
# 0  64d33aec3103df69b8578dcc           0   1PT              22.8
# 1  64d33aec3103df69b8578dcd           1   2PT              44.9
# 2  64d33aec3103df69b8578dce           2   3PT              53.0
# 3  64d33aec3103df69b8578dcf           3   4PT              54.7
# 4  64d33aec3103df69b8578dd0           4   5PT              53.8
# 5  64d33aec3103df69b8578dd1           5   6PT              28.5
# 6  64d33aec3103df69b8578dd2           6   7PT               4.2
# 7  64d33aec3103df69b8578dd3           7   8PT              43.8
# 8  64d33aec3103df69b8578dd4           8   9PT              89.0
# 9  64d33aec3103df69b8578dd5           9  10PT              40.5
#
#    Location of herniation   ODI  가족력  간질성폐질환  고혈압여부  과거수술횟수  ...  \
# 0                       3  51.0  0.0       0      0       0  ...
# 1                       4  26.0  0.0       0      0       0  ...
# ...

# %%
df_ros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1894 entries, 0 to 1893
# Data columns (total 53 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   _id                     1894 non-null   object
#  1   Unnamed: 0              1894 non-null   int64
#  2   환자ID                    1894 non-null   object
#  3   Large Lymphocyte        1894 non-null   float64
#  4   Location of herniation  1894 non-null   int64
#  5   ODI                     462 non-null    float64
#  6   가족력                     1843 non-null   float64
#  7   간질성폐질환                  1894 non-null   int64
#  8   고혈압여부                   1894 non-null   int64
#  9   과거수술횟수                  1894 non-null   int64
#  10  당뇨여부                    1894 non-null   int64
#  11  말초동맥질환여부                1894 non-null   int64
#  12  빈혈여부                    1894 non-null   int64
#  13  성별                      1894 non-null   int64
# ...

# %%
df_ros.columns
# Out:
# Index(['_id', 'Unnamed: 0', '환자ID', 'Large Lymphocyte',
#        'Location of herniation', 'ODI', '가족력', '간질성폐질환', '고혈압여부', '과거수술횟수',
#        '당뇨여부', '말초동맥질환여부', '빈혈여부', '성별', '스테로이드치료', '신부전여부', '신장', '심혈관질환',
#        '암발병여부', '연령', '우울증여부', '입원기간', '입원일자', '종양진행여부', '직업', '체중', '퇴원일자',
#        '헤모글로빈수치', '혈전합병증여부', '환자통증정도', '흡연여부', '통증기간(월)', '수술기법', '수술시간',
#        '수술실패여부', '수술일자', '재발여부', '혈액형', '전방디스크높이(mm)', '후방디스크높이(mm)', '지방축적도',
#        'Instability', 'MF + ES', 'Modic change', 'PI', 'PT', 'Seg Angle(raw)',
#        'Vaccum disc', '골밀도', '디스크단면적', '디스크위치', '척추이동척도', '척추전방위증'],
#       dtype='object')

# %%
df_ros_drops = df_BND.drop(columns=['_id', 'Unnamed: 0', 'Large Lymphocyte',
       'Location of herniation', 'ODI', '가족력', '간질성폐질환', '과거수술횟수', '스테로이드치료', '신장', '입원기간', '입원일자', '종양진행여부', '직업', '체중', '퇴원일자',
       '헤모글로빈수치', '혈전합병증여부', '환자통증정도', '통증기간(월)', '수술일자', '혈액형', 'Instability', 'MF + ES', 'Modic change', 'PI', 'PT', 'Seg Angle(raw)',
       'Vaccum disc', '골밀도', '디스크단면적', '디스크위치',])
df_ros_drops.head(10)
# Out:
#    환자ID  고혈압여부  당뇨여부  말초동맥질환여부  빈혈여부  성별  신부전여부  심혈관질환  암발병여부  연령  ...  흡연여부  \
# 0   1PT      0     0         0     0   2      0      0      0  66  ...     0
# 1   2PT      0     0         0     0   1      0      0      0  47  ...     0
# 2   3PT      0     0         0     0   1      0      0      0  39  ...     0
# 3   4PT      1     0         0     0   1      0      0      0  40  ...     0
# 4   5PT      1     0         0     0   1      0      0      0  42  ...     0
# 5   6PT      0     0         1     0   2      0      0      0  60  ...     1
# 6   7PT      0     1         0     0   1      0      0      0  47  ...     0
# 7   8PT      0     0         0     0   1      0      0      0  55  ...     1
# 8   9PT      0     0         0     0   1      0      0      0  52  ...     1
# 9  10PT      0     0         0     0   1      0      0      0  79  ...     0
#
#    수술기법  수술시간  수술실패여부  재발여부  전방디스크높이(mm)  후방디스크높이(mm)   지방축적도  척추이동척도 척추전방위증
# ...

# %%
df_ros_drops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1894 entries, 0 to 1893
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   환자ID         1894 non-null   object
#  1   고혈압여부        1894 non-null   int64
#  2   당뇨여부         1894 non-null   int64
#  3   말초동맥질환여부     1894 non-null   int64
#  4   빈혈여부         1894 non-null   int64
#  5   성별           1894 non-null   int64
#  6   신부전여부        1894 non-null   int64
#  7   심혈관질환        1894 non-null   int64
#  8   암발병여부        1894 non-null   int64
#  9   연령           1894 non-null   int64
#  10  우울증여부        1894 non-null   int64
#  11  흡연여부         1894 non-null   int64
#  12  수술기법         1813 non-null   object
#  13  수술시간         1840 non-null   float64
#  14  수술실패여부       1894 non-null   int64
#  15  재발여부         1894 non-null   int64
#  16  전방디스크높이(mm)  1894 non-null   float64
#  17  후방디스크높이(mm)  1894 non-null   float64
# ...

# %%
df_ros_drops.describe()
# Out:
#              고혈압여부         당뇨여부     말초동맥질환여부         빈혈여부           성별  \
# count  1894.000000  1894.000000  1894.000000  1894.000000  1894.000000
# mean      0.130940     0.062830     0.004224     0.024287     1.383316
# std       0.337424     0.242721     0.064871     0.153980     0.486323
# min       0.000000     0.000000     0.000000     0.000000     1.000000
# 25%       0.000000     0.000000     0.000000     0.000000     1.000000
# 50%       0.000000     0.000000     0.000000     0.000000     1.000000
# 75%       0.000000     0.000000     0.000000     0.000000     2.000000
# max       1.000000     1.000000     1.000000     1.000000     2.000000
#
#              신부전여부        심혈관질환        암발병여부           연령        우울증여부  \
# count  1894.000000  1894.000000  1894.000000  1894.000000  1894.000000
# mean      0.025343     0.035903     0.013728    41.463569     0.023231
# std       0.157207     0.186097     0.116388    13.444629     0.154143
# ...

# %%
df_ros_drops.describe(include=object)
# Out:
#         환자ID  수술기법  척추이동척도
# count   1894  1813    1894
# unique  1894     2       5
# top      1PT  TELD  Middle
# freq       1  1673    1260

# %%
df_ros_drops['수술실패여부'].value_counts()
# Out:
# 0    1779
# 1     115
# Name: 수술실패여부, dtype: int64

# %%
df_ros_drops['수술실패여부'].unique()
# Out:
# array([0, 1], dtype=int64)
