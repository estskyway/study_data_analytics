# %%
import pymongo as mg
import pandas as pd

# %%
client = mg.MongoClient(host='mongodb://localhost:27017')

# %%
database = client['db_NHIS']

# %%
collection = database['NSC2_BNC_V2_1']

# %%
cursor = collection.find({})

# %%
list_BNC_V2_1 = list(cursor)

# %%
list_BNC_V2_1
# Out:
# [{'_id': ObjectId('64d310fe109af7d76ebf0af9'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0afa'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0afb'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0afc'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0afd'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0afe'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0aff'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29170,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b00'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b01'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b02'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b03'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b04'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b05'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b06'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b07'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41460,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b08'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41460,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b09'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41460,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b0a'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41460,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b0b'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41461,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b0c'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41461,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b0d'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41461,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b0e'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41461,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b0f'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 44760,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b10'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 44760,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b11'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 44760,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b12'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 44760,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b13'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 44760,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b14'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 44760,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b15'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b16'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b17'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b18'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b19'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b1a'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b1b'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b1c'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b1d'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b1e'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b1f'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b20'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b21'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b22'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b23'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41220,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b24'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41220,
#   'GAIBJA_TYPE': 6,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b25'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41220,
#   'GAIBJA_TYPE': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b26'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41220,
#   'GAIBJA_TYPE': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b27'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41220,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b28'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41220,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b29'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 11650,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b2a'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 11650,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b2b'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 11650,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b2c'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41590,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b2d'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41590,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b2e'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26140,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b2f'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26320,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b30'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26320,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b31'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26320,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b32'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26140,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b33'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26140,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b34'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26140,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b35'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26410,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b36'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b37'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b38'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b39'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b3a'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b3b'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b3c'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b3d'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b3e'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b3f'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b40'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b41'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b42'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b43'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b44'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b45'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b46'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b47'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b48'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b49'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27290,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b4a'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27290,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b4b'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27290,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b4c'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27290,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b4d'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27290,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b4e'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b4f'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b50'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b51'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b52'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b53'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b54'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b55'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b56'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b57'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b58'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b59'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b5a'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b5b'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b5c'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b5d'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b5e'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b5f'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b60'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48121,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b61'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48121,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b62'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48121,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b63'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48121,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b64'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48121,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b65'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b66'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b67'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b68'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b69'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b6a'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b6b'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b6c'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b6d'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b6e'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b6f'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b70'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b71'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b72'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b73'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b74'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b75'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b76'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b77'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b78'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b79'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b7a'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b7b'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b7c'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b7d'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b7e'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b7f'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b80'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 6,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b81'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 41570,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b82'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 41570,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b83'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 41570,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 6,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b84'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 41570,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b85'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b86'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b87'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b88'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b89'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b8a'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b8b'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b8c'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b8d'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b8e'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b8f'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b90'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b91'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b92'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b93'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b94'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b95'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b96'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b97'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b98'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b99'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b9a'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b9b'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b9c'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b9d'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b9e'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0b9f'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ba0'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ba1'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ba2'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ba3'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ba4'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ba5'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ba6'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ba7'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ba8'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ba9'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 11200,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0baa'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 11200,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bab'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11305,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bac'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11305,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bad'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11305,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bae'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11305,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0baf'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11305,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bb0'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11305,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bb1'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11305,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bb2'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11305,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bb3'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11305,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bb4'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11290,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bb5'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11290,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bb6'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11290,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bb7'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11290,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bb8'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11290,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bb9'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 47750,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bba'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 47750,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bbb'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 47750,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bbc'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 47750,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bbd'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 47750,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bbe'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 47750,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bbf'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 47750,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bc0'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 47750,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bc1'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 47750,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bc2'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bc3'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bc4'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bc5'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bc6'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bc7'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bc8'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bc9'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bca'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bcb'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bcc'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bcd'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bce'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bcf'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bd0'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bd1'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bd2'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bd3'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bd4'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bd5'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 46790,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bd6'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 46790,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bd7'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 46790,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bd8'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 46790,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bd9'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 46790,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bda'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 46790,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bdb'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 46790,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bdc'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 41463,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bdd'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 41463,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bde'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 41463,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bdf'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 41463,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0be0'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 41463,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0be1'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 41463,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0be2'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 41463,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0be3'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0be4'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0be5'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0be6'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0be7'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0be8'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0be9'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bea'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0beb'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bec'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bed'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bee'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bef'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bf0'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bf1'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bf2'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bf3'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bf4'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bf5'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bf6'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bf7'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bf8'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bf9'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bfa'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bfb'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bfc'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bfd'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bfe'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0bff'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 17781,
#   'SEX': 2,
#   'SGG': 41135,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0c00'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 17781,
#   'SEX': 2,
#   'SGG': 41135,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0c01'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 17781,
#   'SEX': 2,
#   'SGG': 41135,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0c02'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 17781,
#   'SEX': 2,
#   'SGG': 41135,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0c03'),
#   'STD_YYYY': 2006,
# ...
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0e89'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 82310,
#   'SEX': 2,
#   'SGG': 11740,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0e8a'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0e8b'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0e8c'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0e8d'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0e8e'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0e8f'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0e90'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0e91'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0e92'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0e93'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48125,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0e94'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48125,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0e95'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48125,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0e96'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48125,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0e97'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48125,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0e98'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0e99'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0e9a'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0e9b'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0e9c'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0e9d'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0e9e'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0e9f'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ea0'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ea1'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ea2'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ea3'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 44270,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ea4'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 44270,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ea5'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 44270,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ea6'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ea7'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ea8'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ea9'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0eaa'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0eab'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0eac'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ead'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0eae'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0eaf'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0eb0'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0eb1'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0eb2'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0eb3'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43112,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0eb4'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 28170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0eb5'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 28170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0eb6'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 28170,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0eb7'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 28170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0eb8'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 28170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0eb9'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0eba'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ebb'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ebc'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ebd'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ebe'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ebf'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ec0'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ec1'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ec2'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ec3'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ec4'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ec5'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ec6'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ec7'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ec8'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ec9'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0eca'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ecb'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ecc'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ecd'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ece'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ecf'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ed0'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ed1'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ed2'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ed3'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ed4'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ed5'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ed6'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ed7'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ed8'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ed9'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0eda'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0edb'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0edc'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0edd'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ede'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 89809,
#   'SEX': 2,
#   'SGG': 30170,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0edf'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 89809,
#   'SEX': 2,
#   'SGG': 30170,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310fe109af7d76ebf0ee0'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 89809,
#   'SEX': 2,
#   'SGG': 30170,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  ...]

# %%
df_BNC_V2_1 = pd.DataFrame(list_BNC_V2_1)

# %%
df_BNC_V2_1
# Out:
#                             _id  STD_YYYY  RN_INDI  SEX    SGG  GAIBJA_TYPE  \
# 0      64d310fe109af7d76ebf0af9      2002     1433    1  29140            7
# 1      64d310fe109af7d76ebf0afa      2003     1433    1  29140            7
# 2      64d310fe109af7d76ebf0afb      2004     1433    1  29140            7
# 3      64d310fe109af7d76ebf0afc      2005     1433    1  29140            7
# 4      64d310fe109af7d76ebf0afd      2006     1433    1  29140            7
# ...                         ...       ...      ...  ...    ...          ...
# 13022  64d310ff109af7d76ebf3dd7      2012  3000357    2  28237            6
# 13023  64d310ff109af7d76ebf3dd8      2013  3000357    2  28245            2
# 13024  64d310ff109af7d76ebf3dd9      2014  3000357    2  28245            2
# 13025  64d310ff109af7d76ebf3dda      2015  3000357    2  28245            2
# 13026  64d310ff109af7d76ebf3ddb      2015  3000758    1  41287            6
#
#        SMPL_TYPE_CD  CTRB_Q10 G1E_OBJ_YN  DSB_TYPE_CD  DSB_SVRT_CD_V2
# 0                 1       NaN        NaN          NaN             NaN
# 1                 1       NaN        NaN          NaN             NaN
# 2                 1       NaN        NaN          NaN             NaN
# 3                 1       NaN        NaN          NaN             NaN
# 4                 1       NaN        NaN          NaN             NaN
# ...             ...       ...        ...          ...             ...
# 13022             4       NaN        NaN          NaN             NaN
# 13023             4       6.0        NaN          NaN             NaN
# 13024             4       6.0        NaN          NaN             NaN
# 13025             4       7.0        NaN          NaN             NaN
# 13026             4       NaN        NaN          NaN             NaN
#
# [13027 rows x 11 columns]

# %%
df_BNC_V2_1.to_csv('./NSC2_BNC_V2_1.csv')
