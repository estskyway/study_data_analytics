# %%
from wordcloud import WordCloud

# %%
# 한글 문장 리스트
sentences = [
    "오늘 날씨가 좋아서 나들이 가고 싶다.",
    "이 영화는 정말 재미있었어요.",
    "맛있는 음식을 먹으러 갈까요?",
    "운동을 하면 건강에 좋아지는 것 같아요.",
    "공부하기 싫어서 미루고 있어요.",
    "여행 계획을 세우고 있는데 어디로 갈까요?",
    "좋은 책을 읽으면 마음이 편안해져요.",
    "오늘은 친구들과 만나서 재미있게 놀았어요.",
    "새로운 언어를 배우는 것은 어려워도 흥미로워요.",
    "주말에 가족들과 함께 시간을 보내기로 했습니다."
]

sentences = [
    "너무나도 감동적인 영화였습니다. 마지막 장면은 정말로 잊을 수 없네요.",
    "배우들의 연기력이 돋보였던 작품. 특히 주연 배우의 연기가 인상적이었습니다.",
    "시나리오가 상당히 독특하네요. 예상치 못한 플롯 트위스트가 좋았습니다.",
    "음악과 영상미, 그리고 스토리까지 모든 것이 완벽한 영화입니다.",
    "조금 지루한 부분도 있었지만, 전체적으로 볼 만했습니다.",
    "주제가 굉장히 심오하네요. 한 번 보고 이해하기 어렵지만 여러 번 보면서 생각할 거리를 얻은 것 같아요.",
    "개인적으로는 코미디 요소가 좀 더 있었다면 좋았을 것 같아요.",
    "처음부터 끝까지 긴장감 넘치는 스토리로 몰입감 100%였습니다!",
    "생각보다 평점이 낮아서 기대 안 하고 봤는데, 정말 재밌게 본 영화 중 하나입니다!",
    "비록 상업적인 성공은 아니었지만 저에게 많은 감동과 공감을 준 작품입니다."
]

# %% [markdown]
# ## 자연어 처리 위한 형태분석기 적용

# %%
from mecab import MeCab
mecab = MeCab()

# %%
mecab.nouns(sentences[0]), mecab.pos(sentences[0])
# Out:
# (['감동', '영화', '마지막', '장면', '수'],
#  [('너무나', 'MAG'),
#   ('도', 'JX'),
#   ('감동', 'NNG'),
#   ('적', 'XSN'),
#   ('인', 'VCP+ETM'),
#   ('영화', 'NNG'),
#   ('였', 'VCP+EP'),
#   ('습니다', 'EF'),
#   ('.', 'SF'),
#   ('마지막', 'NNG'),
#   ('장면', 'NNG'),
#   ('은', 'JX'),
#   ('정말로', 'MAG'),
#   ('잊', 'VV'),
#   ('을', 'ETM'),
#   ('수', 'NNB'),
#   ('없', 'VA'),
#   ('네요', 'EF'),
#   ('.', 'SF')])

# %%
# 형태분석기 사용해 명사만 추출
morphs_list = list()
for sentence in sentences :
    morphs = mecab.nouns(sentence)
    morphs_list = morphs_list + morphs
morphs_list
# Out:
# ['감동',
#  '영화',
#  '마지막',
#  '장면',
#  '수',
#  '배우',
#  '연기력',
#  '작품',
#  '주연',
#  '배우',
#  '연기',
#  '인상',
#  '시나리오',
#  '예상',
#  '플롯',
#  '트위스트',
#  '음악',
#  '영상미',
#  '스토리',
#  '것',
#  '완벽',
#  '영화',
#  '부분',
#  '전체',
#  '만',
#  '주제',
#  '번',
#  '이해',
#  '번',
#  '생각',
#  '거리',
#  '것',
#  '개인',
#  '코미디',
#  '요소',
#  '것',
#  '처음',
#  '끝',
#  '긴장감',
#  '스토리',
#  '입감',
#  '생각',
#  '평점',
#  '기대',
#  '영화',
#  '중',
#  '하나',
#  '상업',
#  '성공',
#  '저',
#  '감동',
#  '공감',
#  '작품']

# %%
from collections import Counter
nouns_count = Counter(morphs_list)

# %%
# 한글 폰트 경로 설정 (Windows 환경에 맞게 경로 수정)
font_path = 'C:/Windows/Fonts/malgun.ttf'

wordCloud = WordCloud(font_path=font_path, background_color='white')
wordCloud.generate_from_frequencies(nouns_count)

# %%
wordCloud.words_
# Out:
# {'영화': 1.0,
#  '것': 1.0,
#  '감동': 0.6666666666666666,
#  '배우': 0.6666666666666666,
#  '작품': 0.6666666666666666,
#  '스토리': 0.6666666666666666,
#  '번': 0.6666666666666666,
#  '생각': 0.6666666666666666,
#  '마지막': 0.3333333333333333,
#  '장면': 0.3333333333333333,
#  '수': 0.3333333333333333,
#  '연기력': 0.3333333333333333,
#  '주연': 0.3333333333333333,
#  '연기': 0.3333333333333333,
#  '인상': 0.3333333333333333,
#  '시나리오': 0.3333333333333333,
#  '예상': 0.3333333333333333,
#  '플롯': 0.3333333333333333,
#  '트위스트': 0.3333333333333333,
#  '음악': 0.3333333333333333,
#  '영상미': 0.3333333333333333,
#  '완벽': 0.3333333333333333,
#  '부분': 0.3333333333333333,
#  '전체': 0.3333333333333333,
#  '만': 0.3333333333333333,
#  '주제': 0.3333333333333333,
#  '이해': 0.3333333333333333,
#  '거리': 0.3333333333333333,
#  '개인': 0.3333333333333333,
#  '코미디': 0.3333333333333333,
#  '요소': 0.3333333333333333,
#  '처음': 0.3333333333333333,
#  '끝': 0.3333333333333333,
#  '긴장감': 0.3333333333333333,
#  '입감': 0.3333333333333333,
# ...

# %%
import matplotlib.pyplot as plt
plt.imshow(wordCloud)
plt.axis('off')
plt.show()
